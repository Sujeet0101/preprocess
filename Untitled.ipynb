# %%
#current working director
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Code'

# %%
import pandas as pd
import numpy as np

# %%
#loading excel file
dataset = pd.read_excel("hostel_excel.xlsx")
dataset.head()
# Out:
#    Hid               HostelName   District    Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  Bhaktapur  Tibukche Tol       Boys
# 1    2      Friends Boys Hostel  Bhaktapur       Dokchee       Boys
# 2    3  Golden Gate Boys Hostel  Bhaktapur        Talako       Boys
# 3    4       Ajima Girls Hostel  Bhaktapur        Ghakha      Girls
# 4    5  Manjushree Girls Hostel  Bhaktapur      Dudhpati      Girls
#
#    ManagerName  ManagerContact  SingleSeaterPrice  DoubleSeaterPrice  \
# 0  Sujeet Raut      9812038294              12000              11000
# 1  Sujeet Raut      9812038294              11000              10000
# 2  Sujeet Raut      9812038294              13000              12000
# 3  Sujeet Raut      9812038294              12000              11000
# 4  Sujeet Raut      9812038294              12000              11000
#
#    3SeaterPrice  4SeaterPrice  Ratings  \
# 0         10000          9000        3
# 1          9000          8000        2
# ...

# %%
dataset = dataset[['Hid','HostelName','District','Place/City','HostelType','Facilities','Description']]

# %%
dataset.head()
# Out:
#    Hid               HostelName   District    Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  Bhaktapur  Tibukche Tol       Boys
# 1    2      Friends Boys Hostel  Bhaktapur       Dokchee       Boys
# 2    3  Golden Gate Boys Hostel  Bhaktapur        Talako       Boys
# 3    4       Ajima Girls Hostel  Bhaktapur        Ghakha      Girls
# 4    5  Manjushree Girls Hostel  Bhaktapur      Dudhpati      Girls
#
#                                           Facilities  \
# 0  Wifi, Hot and Cold Water, Parking, Laundary, C...
# 1   Wifi, Hot and Cold Water, Parking, Laundary, Fan
# 2  Wifi, Hot and Cold Water, Laundary, CCTV, Gym,...
# 3       Wifi, Hot and Cold Water, Parking, CCTV, Gym
# 4                  Wifi, Hot and Cold Water, Parking
#
#                          Description
# 0               peaceful environment
# 1   located at the heart of the city
# 2  friendly staff, proper clenliness
# 3               peaceful environment
# 4               peaceful environment

# %%
dataset.Facilities = dataset.Facilities.str.replace(" ","")

# %%
dataset.head()
# Out:
#    Hid               HostelName   District    Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  Bhaktapur  Tibukche Tol       Boys
# 1    2      Friends Boys Hostel  Bhaktapur       Dokchee       Boys
# 2    3  Golden Gate Boys Hostel  Bhaktapur        Talako       Boys
# 3    4       Ajima Girls Hostel  Bhaktapur        Ghakha      Girls
# 4    5  Manjushree Girls Hostel  Bhaktapur      Dudhpati      Girls
#
#                                           Facilities  \
# 0  Wifi,HotandColdWater,Parking,Laundary,CCTV,Gym...
# 1          Wifi,HotandColdWater,Parking,Laundary,Fan
# 2         Wifi,HotandColdWater,Laundary,CCTV,Gym,Fan
# 3              Wifi,HotandColdWater,Parking,CCTV,Gym
# 4                       Wifi,HotandColdWater,Parking
#
#                          Description
# 0               peaceful environment
# 1   located at the heart of the city
# 2  friendly staff, proper clenliness
# 3               peaceful environment
# 4               peaceful environment

# %%
dataset['Place/City'] = dataset['Place/City'].apply(lambda x:x.split())

# %%
dataset.head()
# Out:
#    Hid               HostelName   District       Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  Bhaktapur  [Tibukche, Tol]       Boys
# 1    2      Friends Boys Hostel  Bhaktapur        [Dokchee]       Boys
# 2    3  Golden Gate Boys Hostel  Bhaktapur         [Talako]       Boys
# 3    4       Ajima Girls Hostel  Bhaktapur         [Ghakha]      Girls
# 4    5  Manjushree Girls Hostel  Bhaktapur       [Dudhpati]      Girls
#
#                                           Facilities  \
# 0  Wifi,HotandColdWater,Parking,Laundary,CCTV,Gym...
# 1          Wifi,HotandColdWater,Parking,Laundary,Fan
# 2         Wifi,HotandColdWater,Laundary,CCTV,Gym,Fan
# 3              Wifi,HotandColdWater,Parking,CCTV,Gym
# 4                       Wifi,HotandColdWater,Parking
#
#                          Description
# 0               peaceful environment
# 1   located at the heart of the city
# 2  friendly staff, proper clenliness
# 3               peaceful environment
# ...

# %%
dataset['District'] = dataset['District'].apply(lambda x:x.split())

# %%
dataset.head()
# Out:
#    Hid               HostelName     District       Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  [Bhaktapur]  [Tibukche, Tol]       Boys
# 1    2      Friends Boys Hostel  [Bhaktapur]        [Dokchee]       Boys
# 2    3  Golden Gate Boys Hostel  [Bhaktapur]         [Talako]       Boys
# 3    4       Ajima Girls Hostel  [Bhaktapur]         [Ghakha]      Girls
# 4    5  Manjushree Girls Hostel  [Bhaktapur]       [Dudhpati]      Girls
#
#                                           Facilities  \
# 0  Wifi,HotandColdWater,Parking,Laundary,CCTV,Gym...
# 1          Wifi,HotandColdWater,Parking,Laundary,Fan
# 2         Wifi,HotandColdWater,Laundary,CCTV,Gym,Fan
# 3              Wifi,HotandColdWater,Parking,CCTV,Gym
# 4                       Wifi,HotandColdWater,Parking
#
#                          Description
# 0               peaceful environment
# 1   located at the heart of the city
# 2  friendly staff, proper clenliness
# 3               peaceful environment
# ...

# %%
dataset['HostelType'] = dataset['HostelType'].apply(lambda x:x.split())

# %%
dataset.head()
# Out:
#    Hid               HostelName     District       Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  [Bhaktapur]  [Tibukche, Tol]     [Boys]
# 1    2      Friends Boys Hostel  [Bhaktapur]        [Dokchee]     [Boys]
# 2    3  Golden Gate Boys Hostel  [Bhaktapur]         [Talako]     [Boys]
# 3    4       Ajima Girls Hostel  [Bhaktapur]         [Ghakha]    [Girls]
# 4    5  Manjushree Girls Hostel  [Bhaktapur]       [Dudhpati]    [Girls]
#
#                                           Facilities  \
# 0  Wifi,HotandColdWater,Parking,Laundary,CCTV,Gym...
# 1          Wifi,HotandColdWater,Parking,Laundary,Fan
# 2         Wifi,HotandColdWater,Laundary,CCTV,Gym,Fan
# 3              Wifi,HotandColdWater,Parking,CCTV,Gym
# 4                       Wifi,HotandColdWater,Parking
#
#                          Description
# 0               peaceful environment
# 1   located at the heart of the city
# 2  friendly staff, proper clenliness
# 3               peaceful environment
# ...

# %%
dataset['Facilities'] = dataset['Facilities'].apply(lambda x:x.split())

# %%
dataset.head()
# Out:
#    Hid               HostelName     District       Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  [Bhaktapur]  [Tibukche, Tol]     [Boys]
# 1    2      Friends Boys Hostel  [Bhaktapur]        [Dokchee]     [Boys]
# 2    3  Golden Gate Boys Hostel  [Bhaktapur]         [Talako]     [Boys]
# 3    4       Ajima Girls Hostel  [Bhaktapur]         [Ghakha]    [Girls]
# 4    5  Manjushree Girls Hostel  [Bhaktapur]       [Dudhpati]    [Girls]
#
#                                           Facilities  \
# 0  [Wifi,HotandColdWater,Parking,Laundary,CCTV,Gy...
# 1        [Wifi,HotandColdWater,Parking,Laundary,Fan]
# 2       [Wifi,HotandColdWater,Laundary,CCTV,Gym,Fan]
# 3            [Wifi,HotandColdWater,Parking,CCTV,Gym]
# 4                     [Wifi,HotandColdWater,Parking]
#
#                          Description
# 0               peaceful environment
# 1   located at the heart of the city
# 2  friendly staff, proper clenliness
# 3               peaceful environment
# ...

# %%
dataset['Description'] = dataset['Description'].apply(lambda x:x.split())

# %%
dataset.head()
# Out:
#    Hid               HostelName     District       Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  [Bhaktapur]  [Tibukche, Tol]     [Boys]
# 1    2      Friends Boys Hostel  [Bhaktapur]        [Dokchee]     [Boys]
# 2    3  Golden Gate Boys Hostel  [Bhaktapur]         [Talako]     [Boys]
# 3    4       Ajima Girls Hostel  [Bhaktapur]         [Ghakha]    [Girls]
# 4    5  Manjushree Girls Hostel  [Bhaktapur]       [Dudhpati]    [Girls]
#
#                                           Facilities  \
# 0  [Wifi,HotandColdWater,Parking,Laundary,CCTV,Gy...
# 1        [Wifi,HotandColdWater,Parking,Laundary,Fan]
# 2       [Wifi,HotandColdWater,Laundary,CCTV,Gym,Fan]
# 3            [Wifi,HotandColdWater,Parking,CCTV,Gym]
# 4                     [Wifi,HotandColdWater,Parking]
#
#                                 Description
# 0                   [peaceful, environment]
# 1  [located, at, the, heart, of, the, city]
# 2    [friendly, staff,, proper, clenliness]
# ...

# %%
dataset['Tags'] = dataset['District'] + dataset['Place/City'] + dataset['HostelType'] + dataset['Facilities'] + dataset['Description']

# %%
dataset.head()
# Out:
#    Hid               HostelName     District       Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  [Bhaktapur]  [Tibukche, Tol]     [Boys]
# 1    2      Friends Boys Hostel  [Bhaktapur]        [Dokchee]     [Boys]
# 2    3  Golden Gate Boys Hostel  [Bhaktapur]         [Talako]     [Boys]
# 3    4       Ajima Girls Hostel  [Bhaktapur]         [Ghakha]    [Girls]
# 4    5  Manjushree Girls Hostel  [Bhaktapur]       [Dudhpati]    [Girls]
#
#                                           Facilities  \
# 0  [Wifi,HotandColdWater,Parking,Laundary,CCTV,Gy...
# 1        [Wifi,HotandColdWater,Parking,Laundary,Fan]
# 2       [Wifi,HotandColdWater,Laundary,CCTV,Gym,Fan]
# 3            [Wifi,HotandColdWater,Parking,CCTV,Gym]
# 4                     [Wifi,HotandColdWater,Parking]
#
#                                 Description  \
# 0                   [peaceful, environment]
# 1  [located, at, the, heart, of, the, city]
# 2    [friendly, staff,, proper, clenliness]
# ...

# %%
from IPython.display import display
pd.set_option('display.max_columns', None)
dataset.style.set_properties(**{'overflow':'scroll'})
# Out:
# <style type="text/css">
# ...

# %%
dataset.to_excel('processed_dataset.xlsx')

# %%
new_dataset = dataset[['Hid','HostelName','Tags']]

# %%
new_dataset.head()
# Out:
#    Hid               HostelName  \
# 0    1     Big Bell Boys Hostel
# 1    2      Friends Boys Hostel
# 2    3  Golden Gate Boys Hostel
# 3    4       Ajima Girls Hostel
# 4    5  Manjushree Girls Hostel
#
#                                                 Tags
# 0  [Bhaktapur, Tibukche, Tol, Boys, Wifi,HotandCo...
# 1  [Bhaktapur, Dokchee, Boys, Wifi,HotandColdWate...
# 2  [Bhaktapur, Talako, Boys, Wifi,HotandColdWater...
# 3  [Bhaktapur, Ghakha, Girls, Wifi,HotandColdWate...
# 4  [Bhaktapur, Dudhpati, Girls, Wifi,HotandColdWa...

# %%
new_dataset['Tags'] = new_dataset['Tags'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2548\3820637464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataset['Tags'] = new_dataset['Tags'].apply(lambda x:" ".join(x))

# %%
new_dataset.head()
# Out:
#    Hid               HostelName  \
# 0    1     Big Bell Boys Hostel
# 1    2      Friends Boys Hostel
# 2    3  Golden Gate Boys Hostel
# 3    4       Ajima Girls Hostel
# 4    5  Manjushree Girls Hostel
#
#                                                 Tags
# 0  Bhaktapur Tibukche Tol Boys Wifi,HotandColdWat...
# 1  Bhaktapur Dokchee Boys Wifi,HotandColdWater,Pa...
# 2  Bhaktapur Talako Boys Wifi,HotandColdWater,Lau...
# 3  Bhaktapur Ghakha Girls Wifi,HotandColdWater,Pa...
# 4  Bhaktapur Dudhpati Girls Wifi,HotandColdWater,...

# %%
new_dataset['Tags'][0]
# Out:
# 'Bhaktapur Tibukche Tol Boys Wifi,HotandColdWater,Parking,Laundary,CCTV,Gym,Fan peaceful environment'

# %%
new_dataset['Tags'] = new_dataset['Tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2548\397756451.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataset['Tags'] = new_dataset['Tags'].apply(lambda x:x.lower())

# %%
new_dataset.head()
# Out:
#    Hid               HostelName  \
# 0    1     Big Bell Boys Hostel
# 1    2      Friends Boys Hostel
# 2    3  Golden Gate Boys Hostel
# 3    4       Ajima Girls Hostel
# 4    5  Manjushree Girls Hostel
#
#                                                 Tags
# 0  bhaktapur tibukche tol boys wifi,hotandcoldwat...
# 1  bhaktapur dokchee boys wifi,hotandcoldwater,pa...
# 2  bhaktapur talako boys wifi,hotandcoldwater,lau...
# 3  bhaktapur ghakha girls wifi,hotandcoldwater,pa...
# 4  bhaktapur dudhpati girls wifi,hotandcoldwater,...

# %%
new_dataset['Tags']
# Out:
# 0     bhaktapur tibukche tol boys wifi,hotandcoldwat...
# 1     bhaktapur dokchee boys wifi,hotandcoldwater,pa...
# 2     bhaktapur talako boys wifi,hotandcoldwater,lau...
# 3     bhaktapur ghakha girls wifi,hotandcoldwater,pa...
# 4     bhaktapur dudhpati girls wifi,hotandcoldwater,...
#                             ...
# 75    kathmandu koteshwor girls wifi,hotandcoldwater...
# 76    kathmandu sukhedhara girls wifi,hotandcoldwate...
# 77    kathmandu kapan girls wifi,hotandcoldwater,par...
# 78    kathmandu rato pul girls wifi,hotandcoldwater,...
# 79    kathmandu shankhamul girls wifi,hotandcoldwate...
# Name: Tags, Length: 80, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# !pip freeze
# Out:
# distlib==0.3.6
# filelock==3.9.0
# fonttools==4.38.0
# kiwisolver==1.4.4
# numpy==1.24.1
# packaging==23.0
# Pillow==9.4.0
# platformdirs==2.6.2
# pyparsing==3.0.9
# pytz==2022.7
# six==1.16.0
# virtualenv==20.17.1

# %%
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 8.2/8.2 MB 3.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 42.2/42.2 MB 3.0 MB/s eta 0:00:00
# ...
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# ...
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# ...
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words='english')

# %%
tfidf_matrix = tfidf.fit_transform(new_dataset['Tags'])

# %%
from sklearn.metrics.pairwise import linear_kernel

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
indices = pd.Series(new_dataset.index, index=new_dataset['HostelName'])
indices
# Out:
# HostelName
# Big Bell Boys Hostel        0
# Friends Boys Hostel         1
# Golden Gate Boys Hostel     2
# Ajima Girls Hostel          3
# Manjushree Girls Hostel     4
#                            ..
# Rigel Girls Hostel         75
#  Pricha Girls Hostel       76
# Suhana Girls Hostel        77
# Beehive Girls Hostel       78
# Samikshya Girls Hostel     79
# Length: 80, dtype: int64

# %%
indices['Ajima Girls Hostel']
# Out:
# 3

# %%
def get_recommendations(name, cosine_sim=cosine_sim):
    idx = indices[name]
    sim_scores = enumerate(cosine_sim[idx])
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[0:5]
    
    sim_index = [i[0] for i in sim_scores]
    print(new_dataset["HostelName"].iloc[sim_index])

# %%
get_recommendations('Manjushree Girls Hostel')
# Out:
# 4       Manjushree Girls Hostel
# 10          Krishna Boys Hostel
# 3            Ajima Girls Hostel
# 9     Siddhi Laxmi Girls Hostel
# 33                 Women Hostel
# Name: HostelName, dtype: object

# %%
get_recommendations('Ajima Girls Hostel')
# Out:
# 3            Ajima Girls Hostel
# 4       Manjushree Girls Hostel
# 9     Siddhi Laxmi Girls Hostel
# 79       Samikshya Girls Hostel
# 77          Suhana Girls Hostel
# Name: HostelName, dtype: object
