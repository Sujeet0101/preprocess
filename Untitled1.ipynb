# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Code'

# %%
import pandas as pd
import numpy as np

# %%
#loading excel file
dataset = pd.read_excel("hostel_excel.xlsx")
dataset.head(10)
# Out:
#    Hid                 HostelName   District       Place/City HostelType  \
# 0    1       Big Bell Boys Hostel  Bhaktapur     Tibukche Tol       Boys
# 1    2        Friends Boys Hostel  Bhaktapur          Dokchee       Boys
# 2    3    Golden Gate Boys Hostel  Bhaktapur           Talako       Boys
# 3    4         Ajima Girls Hostel  Bhaktapur           Ghakha      Girls
# 4    5    Manjushree Girls Hostel  Bhaktapur         Dudhpati      Girls
# 5    6        Swastik Boys Hostel  Bhaktapur        Coche Tol       Boys
# 6    7    Sweet Home Girls Hostel  Bhaktapur      Lasku Dhoka      Girls
# 7    8         Pagoda Boys Hostel  Bhaktapur  Taumadhi Square       Boys
# 8    9         Subha Girls Hostel  Bhaktapur   Pottery Square      Girls
# 9   10  Siddhi Laxmi Girls Hostel  Bhaktapur       Kwache Tol      Girls
#
#    ManagerName  ManagerContact  SingleSeaterPrice  DoubleSeaterPrice  \
# 0  Sujeet Raut      9812038294              12000              11000
# ...

# %%
indices = pd.Series(dataset.index, index=dataset['HostelName'])

# %%
indices['Big Bell Boys Hostel']
# Out:
# 0

# %%
import re

# %%
def get_name(string,name_list):
    idx = indices[string]
    for name in name_list:
        match = re.search(r'\b%s\b'%(name),string)
        if match:
            return(name)
    print(get_name(string,name_list))

# %%
get_name('Big Bell Boys Hostel',name_list)
# Out:
# 'Big Bell Boys Hostel'
