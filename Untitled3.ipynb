# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Code'

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_excel("hostel_excel.xlsx")
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 dataset = pd.read_excel("hostel_excel.xlsx")
#       2 dataset.head()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_base.py:1376, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1374     ext = "xls"
#    1375 else:
# -> 1376     ext = inspect_excel_format(
#    1377         content_or_path=path_or_buffer, storage_options=storage_options
#    1378     )
#    1379     if ext is None:
#    1380         raise ValueError(
#    1381             "Excel file format cannot be determined, you must specify "
#    1382             "an engine manually."
#    1383         )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_base.py:1250, in inspect_excel_format(content_or_path, storage_options)
#    1247 if isinstance(content_or_path, bytes):
#    1248     content_or_path = BytesIO(content_or_path)
# -> 1250 with get_handle(
#    1251     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1252 ) as handle:
#    1253     stream = handle.handle
#    1254     stream.seek(0)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\common.py:795, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#    (...)
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
# --> 795         handle = open(handle, ioargs.mode)
#     796     handles.append(handle)
#     798 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hostel_excel.xlsx'

# %%
dataset.head()
# Out:
#    Unnamed: 0  Hid               HostelName       District  \
# 0           0    1     Big Bell Boys Hostel  ['Bhaktapur']
# 1           1    2      Friends Boys Hostel  ['Bhaktapur']
# 2           2    3  Golden Gate Boys Hostel  ['Bhaktapur']
# 3           3    4       Ajima Girls Hostel  ['Bhaktapur']
# 4           4    5  Manjushree Girls Hostel  ['Bhaktapur']
#
#             Place/City HostelType  \
# 0  ['Tibukche', 'Tol']   ['Boys']
# 1          ['Dokchee']   ['Boys']
# 2           ['Talako']   ['Boys']
# 3           ['Ghakha']  ['Girls']
# 4         ['Dudhpati']  ['Girls']
#
#                                           Facilities  \
# 0  ['Wifi,HotandColdWater,Parking,Laundary,CCTV,G...
# 1      ['Wifi,HotandColdWater,Parking,Laundary,Fan']
# 2     ['Wifi,HotandColdWater,Laundary,CCTV,Gym,Fan']
# 3          ['Wifi,HotandColdWater,Parking,CCTV,Gym']
# 4                   ['Wifi,HotandColdWater,Parking']
#
#                                          Description  \
# 0                        ['peaceful', 'environment']
# 1  ['located', 'at', 'the', 'heart', 'of', 'the',...
# 2     ['friendly', 'staff,', 'proper', 'clenliness']
# 3                        ['peaceful', 'environment']
# 4                        ['peaceful', 'environment']
#
#                                                 Tags
# 0  ['Bhaktapur', 'Tibukche', 'Tol', 'Boys', 'Wifi...
# 1  ['Bhaktapur', 'Dokchee', 'Boys', 'Wifi,HotandC...
# 2  ['Bhaktapur', 'Talako', 'Boys', 'Wifi,HotandCo...
# 3  ['Bhaktapur', 'Ghakha', 'Girls', 'Wifi,HotandC...
# 4  ['Bhaktapur', 'Dudhpati', 'Girls', 'Wifi,Hotan...

# %%
dataset = dataset[['Hid','HostelName','District','Place/City','HostelType','Facilities','Description']]

# %%
dataset.head()
# Out:
#    Hid               HostelName   District    Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  Bhaktapur  Tibukche Tol       Boys
# 1    2      Friends Boys Hostel  Bhaktapur       Dokchee       Boys
# 2    3  Golden Gate Boys Hostel  Bhaktapur        Talako       Boys
# 3    4       Ajima Girls Hostel  Bhaktapur        Ghakha      Girls
# 4    5  Manjushree Girls Hostel  Bhaktapur      Dudhpati      Girls
#
#                                           Facilities  \
# 0  Wifi, Hot and Cold Water, Parking, Laundary, C...
# 1   Wifi, Hot and Cold Water, Parking, Laundary, Fan
# 2  Wifi, Hot and Cold Water, Laundary, CCTV, Gym,...
# 3       Wifi, Hot and Cold Water, Parking, CCTV, Gym
# 4                  Wifi, Hot and Cold Water, Parking
#
#                          Description
# 0               peaceful environment
# 1   located at the heart of the city
# 2  friendly staff, proper clenliness
# 3               peaceful environment
# 4               peaceful environment

# %%
dataset.Facilities = dataset.Facilities.str.replace(" ","")
dataset.head()
# Out:
#    Hid               HostelName   District    Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  Bhaktapur  Tibukche Tol       Boys
# 1    2      Friends Boys Hostel  Bhaktapur       Dokchee       Boys
# 2    3  Golden Gate Boys Hostel  Bhaktapur        Talako       Boys
# 3    4       Ajima Girls Hostel  Bhaktapur        Ghakha      Girls
# 4    5  Manjushree Girls Hostel  Bhaktapur      Dudhpati      Girls
#
#                                           Facilities  \
# 0  Wifi,HotandColdWater,Parking,Laundary,CCTV,Gym...
# 1          Wifi,HotandColdWater,Parking,Laundary,Fan
# 2         Wifi,HotandColdWater,Laundary,CCTV,Gym,Fan
# 3              Wifi,HotandColdWater,Parking,CCTV,Gym
# 4                       Wifi,HotandColdWater,Parking
#
#                          Description
# 0               peaceful environment
# 1   located at the heart of the city
# 2  friendly staff, proper clenliness
# 3               peaceful environment
# 4               peaceful environment

# %%
dataset['Place/City'] = dataset['Place/City'].apply(lambda x:x.split())
dataset['District'] = dataset['District'].apply(lambda x:x.split())

# %%
dataset.head()
# Out:
#    Hid               HostelName     District       Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  [Bhaktapur]  [Tibukche, Tol]       Boys
# 1    2      Friends Boys Hostel  [Bhaktapur]        [Dokchee]       Boys
# 2    3  Golden Gate Boys Hostel  [Bhaktapur]         [Talako]       Boys
# 3    4       Ajima Girls Hostel  [Bhaktapur]         [Ghakha]      Girls
# 4    5  Manjushree Girls Hostel  [Bhaktapur]       [Dudhpati]      Girls
#
#                                           Facilities  \
# 0  Wifi,HotandColdWater,Parking,Laundary,CCTV,Gym...
# 1          Wifi,HotandColdWater,Parking,Laundary,Fan
# 2         Wifi,HotandColdWater,Laundary,CCTV,Gym,Fan
# 3              Wifi,HotandColdWater,Parking,CCTV,Gym
# 4                       Wifi,HotandColdWater,Parking
#
#                          Description
# 0               peaceful environment
# 1   located at the heart of the city
# 2  friendly staff, proper clenliness
# 3               peaceful environment
# 4               peaceful environment

# %%
dataset['HostelType'] = dataset['HostelType'].apply(lambda x:x.split())
dataset['Facilities'] = dataset['Facilities'].apply(lambda x:x.split())
dataset['Description'] = dataset['Description'].apply(lambda x:x.split())
dataset.head()
# Out:
#    Hid               HostelName     District       Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  [Bhaktapur]  [Tibukche, Tol]     [Boys]
# 1    2      Friends Boys Hostel  [Bhaktapur]        [Dokchee]     [Boys]
# 2    3  Golden Gate Boys Hostel  [Bhaktapur]         [Talako]     [Boys]
# 3    4       Ajima Girls Hostel  [Bhaktapur]         [Ghakha]    [Girls]
# 4    5  Manjushree Girls Hostel  [Bhaktapur]       [Dudhpati]    [Girls]
#
#                                           Facilities  \
# 0  [Wifi,HotandColdWater,Parking,Laundary,CCTV,Gy...
# 1        [Wifi,HotandColdWater,Parking,Laundary,Fan]
# 2       [Wifi,HotandColdWater,Laundary,CCTV,Gym,Fan]
# 3            [Wifi,HotandColdWater,Parking,CCTV,Gym]
# 4                     [Wifi,HotandColdWater,Parking]
#
#                                 Description
# 0                   [peaceful, environment]
# 1  [located, at, the, heart, of, the, city]
# 2    [friendly, staff,, proper, clenliness]
# 3                   [peaceful, environment]
# 4                   [peaceful, environment]

# %%
dataset['Tags'] = dataset['District'] + dataset['Place/City'] + dataset['HostelType'] + dataset['Facilities'] + dataset['Description']
dataset.head()
# Out:
#    Hid               HostelName     District       Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  [Bhaktapur]  [Tibukche, Tol]     [Boys]
# 1    2      Friends Boys Hostel  [Bhaktapur]        [Dokchee]     [Boys]
# 2    3  Golden Gate Boys Hostel  [Bhaktapur]         [Talako]     [Boys]
# 3    4       Ajima Girls Hostel  [Bhaktapur]         [Ghakha]    [Girls]
# 4    5  Manjushree Girls Hostel  [Bhaktapur]       [Dudhpati]    [Girls]
#
#                                           Facilities  \
# 0  [Wifi,HotandColdWater,Parking,Laundary,CCTV,Gy...
# 1        [Wifi,HotandColdWater,Parking,Laundary,Fan]
# 2       [Wifi,HotandColdWater,Laundary,CCTV,Gym,Fan]
# 3            [Wifi,HotandColdWater,Parking,CCTV,Gym]
# 4                     [Wifi,HotandColdWater,Parking]
#
#                                 Description  \
# 0                   [peaceful, environment]
# 1  [located, at, the, heart, of, the, city]
# 2    [friendly, staff,, proper, clenliness]
# 3                   [peaceful, environment]
# 4                   [peaceful, environment]
#
#                                                 Tags
# 0  [Bhaktapur, Tibukche, Tol, Boys, Wifi,HotandCo...
# 1  [Bhaktapur, Dokchee, Boys, Wifi,HotandColdWate...
# 2  [Bhaktapur, Talako, Boys, Wifi,HotandColdWater...
# 3  [Bhaktapur, Ghakha, Girls, Wifi,HotandColdWate...
# 4  [Bhaktapur, Dudhpati, Girls, Wifi,HotandColdWa...

# %%
dataset['Tags'] = dataset['Tags'].apply(lambda x:" ".join(x))

# %%
dataset.head(Tags)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 dataset.head(Tags)
#
# NameError: name 'dataset' is not defined

# %%
dataset['District'] = dataset['District'].apply(lambda x:" ".join(x))
dataset['Place/City'] = dataset['Place/City'].apply(lambda x:" ".join(x))
dataset['HostelType'] = dataset['HostelType'].apply(lambda x:" ".join(x))
dataset['Facilities'] = dataset['Facilities'].apply(lambda x:" ".join(x))
dataset['Description'] = dataset['Description'].apply(lambda x:" ".join(x))
dataset.head()
# Out:
#    Hid               HostelName   District    Place/City HostelType  \
# 0    1     Big Bell Boys Hostel  Bhaktapur  Tibukche Tol       Boys
# 1    2      Friends Boys Hostel  Bhaktapur       Dokchee       Boys
# 2    3  Golden Gate Boys Hostel  Bhaktapur        Talako       Boys
# 3    4       Ajima Girls Hostel  Bhaktapur        Ghakha      Girls
# 4    5  Manjushree Girls Hostel  Bhaktapur      Dudhpati      Girls
#
#                                           Facilities  \
# 0  Wifi,HotandColdWater,Parking,Laundary,CCTV,Gym...
# 1          Wifi,HotandColdWater,Parking,Laundary,Fan
# 2         Wifi,HotandColdWater,Laundary,CCTV,Gym,Fan
# 3              Wifi,HotandColdWater,Parking,CCTV,Gym
# 4                       Wifi,HotandColdWater,Parking
#
#                          Description  \
# 0               peaceful environment
# 1   located at the heart of the city
# 2  friendly staff, proper clenliness
# 3               peaceful environment
# 4               peaceful environment
#
#                                                 Tags
# 0  Bhaktapur Tibukche Tol Boys Wifi,HotandColdWat...
# 1  Bhaktapur Dokchee Boys Wifi,HotandColdWater,Pa...
# 2  Bhaktapur Talako Boys Wifi,HotandColdWater,Lau...
# 3  Bhaktapur Ghakha Girls Wifi,HotandColdWater,Pa...
# 4  Bhaktapur Dudhpati Girls Wifi,HotandColdWater,...

# %%
from IPython.display import display
pd.set_option('display.max_columns', None)
dataset.style.set_properties(**{'overflow':'scroll'})
# Out:
# <style type="text/css">
# #T_ec044_row0_col0, #T_ec044_row0_col1, #T_ec044_row0_col2, #T_ec044_row0_col3, #T_ec044_row0_col4, #T_ec044_row0_col5, #T_ec044_row0_col6, #T_ec044_row0_col7, #T_ec044_row1_col0, #T_ec044_row1_col1, #T_ec044_row1_col2, #T_ec044_row1_col3, #T_ec044_row1_col4, #T_ec044_row1_col5, #T_ec044_row1_col6, #T_ec044_row1_col7, #T_ec044_row2_col0, #T_ec044_row2_col1, #T_ec044_row2_col2, #T_ec044_row2_col3, #T_ec044_row2_col4, #T_ec044_row2_col5, #T_ec044_row2_col6, #T_ec044_row2_col7, #T_ec044_row3_col0, #T_ec044_row3_col1, #T_ec044_row3_col2, #T_ec044_row3_col3, #T_ec044_row3_col4, #T_ec044_row3_col5, #T_ec044_row3_col6, #T_ec044_row3_col7, #T_ec044_row4_col0, #T_ec044_row4_col1, #T_ec044_row4_col2, #T_ec044_row4_col3, #T_ec044_row4_col4, #T_ec044_row4_col5, #T_ec044_row4_col6, #T_ec044_row4_col7, #T_ec044_row5_col0, #T_ec044_row5_col1, #T_ec044_row5_col2, #T_ec044_row5_col3, #T_ec044_row5_col4, #T_ec044_row5_col5, #T_ec044_row5_col6, #T_ec044_row5_col7, #T_ec044_row6_col0, #T_ec044_row6_col1, #T_ec044_row6_col2, #T_ec044_row6_col3, #T_ec044_row6_col4, #T_ec044_row6_col5, #T_ec044_row6_col6, #T_ec044_row6_col7, #T_ec044_row7_col0, #T_ec044_row7_col1, #T_ec044_row7_col2, #T_ec044_row7_col3, #T_ec044_row7_col4, #T_ec044_row7_col5, #T_ec044_row7_col6, #T_ec044_row7_col7, #T_ec044_row8_col0, #T_ec044_row8_col1, #T_ec044_row8_col2, #T_ec044_row8_col3, #T_ec044_row8_col4, #T_ec044_row8_col5, #T_ec044_row8_col6, #T_ec044_row8_col7, #T_ec044_row9_col0, #T_ec044_row9_col1, #T_ec044_row9_col2, #T_ec044_row9_col3, #T_ec044_row9_col4, #T_ec044_row9_col5, #T_ec044_row9_col6, #T_ec044_row9_col7, #T_ec044_row10_col0, #T_ec044_row10_col1, #T_ec044_row10_col2, #T_ec044_row10_col3, #T_ec044_row10_col4, #T_ec044_row10_col5, #T_ec044_row10_